# %%
import robotic as ry
import time
import numpy as np
import os
import time
import matplotlib.pyplot as plt
C = ry.Config()
C.addFile("rai-robotModels/scenarios/pandasFight.g")

C.setJointState(np.array([ 0.  , -1.  ,  0.  , -2.  ,  0.  ,  2.  ,  0.  ,  0.  ,
       -1.  ,  0.  , -2.  ,  0.  ,  2.  ,  0.]))
q0 = C.getJointState()

# %%
komo = ry.KOMO(C, 10, 10, 2, True)
komo.addControlObjective([], 0, 1e-1) 
komo.addControlObjective([], 2, 1e0)
komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq,[1e1])
komo.addObjective([5,10], ry.FS.positionDiff, ['r_gripper', "shi-h1"], ry.OT.eq, [1e1])
komo.addObjective([5.,10.], ry.FS.scalarProductZZ, ['r_gripper', 'shi-h1'], ry.OT.eq, [1e1], [])
komo.addObjective([5.,10.], ry.FS.scalarProductXZ, ['shi-h1','r_gripper'], ry.OT.eq, [1e1], [])
komo.addObjective([5.,10.], ry.FS.scalarProductXZ, ['r_gripper','shi-h1'], ry.OT.eq, [1e1], [])

# komo.addObjective([3,5], ry.FS.position,['l_gripper'], ry.OT.eq, [1e1], grasp_pos + np.array([0, 0, 0.5]) )

# komo.addObjective([5,10], ry.FS.position,['l_gripper'], ry.OT.eq, [1e1], grasp_pos )
# komo.addObjective([5,10], ry.FS.vectorX, ['l_gripper'], ry.OT.eq, [1e1],normal)

ret = ry.NLP_Solver() \
.setProblem(komo.nlp()) \
.setOptions( stopTolerance=1e-2, verbose=4 ) \
.solve()

take_shield = komo.getPath()
# Out:
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):12133.5 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):     9427.2  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    7039.78  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    5080.29  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):    3548.65  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    2467.87  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):    1637.22  ACCEPT
# --newton-- it:   7  |Delta|:        0.2  alpha:          1  evals:   8  f(y):    980.115  ACCEPT
# --newton-- it:   8  |Delta|:        0.2  alpha:          1  evals:   9  f(y):    482.727  ACCEPT
# --newton-- it:   9  |Delta|:        0.2  alpha:          1  evals:  10  f(y):    169.873  ACCEPT
# --newton-- it:  10  |Delta|:        0.2  alpha:          1  evals:  11  f(y):    38.8635  ACCEPT
# --newton-- it:  11  |Delta|:        0.2  alpha:          1  evals:  12  f(y):    20.6189  ACCEPT
# --newton-- it:  12  |Delta|:    0.13741  alpha:          1  evals:  13  f(y):    8.69644  ACCEPT
# --newton-- it:  13  |Delta|:  0.0991466  alpha:          1  evals:  14  f(y):    8.10654  ACCEPT
# --newton-- it:  14  |Delta|:  0.0784913  alpha:          1  evals:  15  f(y):    7.75915  ACCEPT
# --newton-- it:  15  |Delta|:  0.0656077  alpha:          1  evals:  16  f(y):    7.50778  ACCEPT
# --newton-- it:  16  |Delta|:  0.0563804  alpha:          1  evals:  17  f(y):    7.31687  ACCEPT
# --newton-- it:  17  |Delta|:  0.0490998  alpha:          1  evals:  18  f(y):    7.16883  ACCEPT
# --newton-- it:  18  |Delta|:  0.0429596  alpha:          1  evals:  19  f(y):    7.05272  ACCEPT
# --newton-- it:  19  |Delta|:  0.0376862  alpha:          1  evals:  20  f(y):    6.96094  ACCEPT
# --newton-- it:  20  |Delta|:  0.0330776  alpha:          1  evals:  21  f(y):    6.88788  ACCEPT
# --newton-- it:  21  |Delta|:  0.0290467  alpha:          1  evals:  22  f(y):    6.82927  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:  22  A(x):    6.82927  f:    6.08319  g:          0  h:    8.64424  |x-x'|:    1.88807 	stop:DeltaConverge
# ==nlp== it:   1  evals:  22  A(x):    11.3057  mu:5
# --newton-- it:  22  |Delta|:  0.0554424  alpha:          1  evals:  23  f(y):    11.0296  ACCEPT
# --newton-- it:  23  |Delta|:  0.0349614  alpha:          1  evals:  24  f(y):    10.5665  ACCEPT
# --newton-- it:  24  |Delta|:  0.0285891  alpha:          1  evals:  25  f(y):    10.5024  ACCEPT
# --newton-- it:  25  |Delta|:  0.0240843  alpha:          1  evals:  26  f(y):    10.4619  ACCEPT
# --newton-- it:  26  |Delta|:  0.0206944  alpha:          1  evals:  27  f(y):    10.4306  ACCEPT
# --newton-- it:  27  |Delta|:   0.017919  alpha:          1  evals:  28  f(y):     10.404  ACCEPT
# --newton-- it:  28  |Delta|:  0.0155767  alpha:          1  evals:  29  f(y):    10.3832  ACCEPT
# --newton-- it:  29  |Delta|:   0.013555  alpha:          1  evals:  30  f(y):    10.3647  ACCEPT
# --newton-- it:  30  |Delta|:  0.0118054  alpha:          1  evals:  31  f(y):      10.35  ACCEPT
# --newton-- it:  31  |Delta|:   0.010279  alpha:          1  evals:  32  f(y):    10.3364  ACCEPT
# --newton-- it:  32  |Delta|:  0.0089465  alpha:          1  evals:  33  f(y):    10.3256  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  33  A(x):    10.3256  f:    6.07824  g:          0  h:     7.3796  |x-x'|:   0.214171 	stop:DeltaConverge
# ==nlp== it:   2  evals:  33  A(x):    28.3061  mu:25
# --newton-- it:  33  |Delta|:  0.0201683  alpha:          1  evals:  34  f(y):    28.2642  ACCEPT
# --newton-- it:  34  |Delta|: 0.00993494  alpha:          1  evals:  35  f(y):    28.1664  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals:  35  A(x):    28.1664  f:    6.12575  g:          0  h:    7.13247  |x-x'|:  0.0234187 	stop:DeltaConverge
# ==nlp== it:   3  evals:  35  A(x):    117.263  mu:125
# --newton-- it:  35  |Delta|: 0.00836172  alpha:          1  evals:  36  f(y):    117.238  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   3  evals:  36  A(x):    117.238  f:    6.14883  g:          0  h:    7.12694  |x-x'|: 0.00836172 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):117.238

# %%
komo = ry.KOMO(C, 10, 10, 2, True)
komo.addControlObjective([], 0, 1e-1) 
komo.addControlObjective([], 2, 1e0)
komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq,[1e1])
komo.addObjective([5,10], ry.FS.positionDiff, ['l_gripper', "sword_0"], ry.OT.eq, [1e1])
komo.addObjective([5.,10.], ry.FS.scalarProductYZ, ['sword_0','l_gripper'], ry.OT.eq, [1e1], [])
komo.addObjective([5.,10.], ry.FS.scalarProductXZ, ['sword_0','l_gripper'], ry.OT.eq, [1e1], [])
komo.addObjective([5.,10.], ry.FS.scalarProductXX, ['l_gripper','sword_0'], ry.OT.eq, [1e1], [])

# komo.addObjective([3,5], ry.FS.position,['l_gripper'], ry.OT.eq, [1e1], grasp_pos + np.array([0, 0, 0.5]) )

# komo.addObjective([5,10], ry.FS.position,['l_gripper'], ry.OT.eq, [1e1], grasp_pos )
# komo.addObjective([5,10], ry.FS.vectorX, ['l_gripper'], ry.OT.eq, [1e1],normal)

ret = ry.NLP_Solver() \
.setProblem(komo.nlp()) \
.setOptions( stopTolerance=1e-2, verbose=4 ) \
.solve()

take_sword= komo.getPath()
# Out:
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):11392 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    8811.41  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    6700.83  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    4841.77  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):    3200.89  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    2093.78  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):    1364.68  ACCEPT
# --newton-- it:   7  |Delta|:        0.2  alpha:          1  evals:   8  f(y):    851.123  ACCEPT
# --newton-- it:   8  |Delta|:        0.2  alpha:          1  evals:   9  f(y):    459.243  ACCEPT
# --newton-- it:   9  |Delta|:        0.2  alpha:          1  evals:  10  f(y):    212.427  ACCEPT
# --newton-- it:  10  |Delta|:        0.2  alpha:          1  evals:  11  f(y):    83.2659  ACCEPT
# --newton-- it:  11  |Delta|:        0.2  alpha:          1  evals:  12  f(y):    37.4745  ACCEPT
# --newton-- it:  12  |Delta|:        0.2  alpha:          1  evals:  13  f(y):    15.0349  ACCEPT
# --newton-- it:  13  |Delta|:    0.16686  alpha:          1  evals:  14  f(y):    7.74912  ACCEPT
# --newton-- it:  14  |Delta|:   0.115261  alpha:          1  evals:  15  f(y):    6.71301  ACCEPT
# --newton-- it:  15  |Delta|:  0.0886818  alpha:          1  evals:  16  f(y):    6.35452  ACCEPT
# --newton-- it:  16  |Delta|:  0.0721278  alpha:          1  evals:  17  f(y):    6.12903  ACCEPT
# --newton-- it:  17  |Delta|:  0.0611066  alpha:          1  evals:  18  f(y):    5.96649  ACCEPT
# --newton-- it:  18  |Delta|:  0.0530723  alpha:          1  evals:  19  f(y):     5.8422  ACCEPT
# --newton-- it:  19  |Delta|:   0.046698  alpha:          1  evals:  20  f(y):    5.74424  ACCEPT
# --newton-- it:  20  |Delta|:  0.0412939  alpha:          1  evals:  21  f(y):     5.6657  ACCEPT
# --newton-- it:  21  |Delta|:  0.0366386  alpha:          1  evals:  22  f(y):    5.60207  ACCEPT
# --newton-- it:  22  |Delta|:  0.0325042  alpha:          1  evals:  23  f(y):    5.55011  ACCEPT
# --newton-- it:  23  |Delta|:  0.0288379  alpha:          1  evals:  24  f(y):    5.50737  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:  24  A(x):    5.50737  f:    5.31823  g:          0  h:    2.43362  |x-x'|:    2.03662 	stop:DeltaConverge
# ==nlp== it:   1  evals:  24  A(x):    6.64222  mu:5
# --newton-- it:  24  |Delta|:  0.0720077  alpha:          1  evals:  25  f(y):    5.84451  ACCEPT
# --newton-- it:  25  |Delta|:  0.0404348  alpha:          1  evals:  26  f(y):    5.74843  ACCEPT
# --newton-- it:  26  |Delta|:  0.0329606  alpha:          1  evals:  27  f(y):    5.69438  ACCEPT
# --newton-- it:  27  |Delta|:  0.0280476  alpha:          1  evals:  28  f(y):    5.65341  ACCEPT
# --newton-- it:  28  |Delta|:  0.0242615  alpha:          1  evals:  29  f(y):    5.62099  ACCEPT
# --newton-- it:  29  |Delta|:  0.0209871  alpha:          1  evals:  30  f(y):    5.59503  ACCEPT
# --newton-- it:  30  |Delta|:   0.018361  alpha:          1  evals:  31  f(y):    5.57356  ACCEPT
# --newton-- it:  31  |Delta|:  0.0161522  alpha:          1  evals:  32  f(y):    5.55574  ACCEPT
# --newton-- it:  32  |Delta|:  0.0141779  alpha:          1  evals:  33  f(y):    5.54076  ACCEPT
# --newton-- it:  33  |Delta|:  0.0124436  alpha:          1  evals:  34  f(y):    5.52801  ACCEPT
# --newton-- it:  34  |Delta|:    0.01092  alpha:          1  evals:  35  f(y):    5.51705  ACCEPT
# --newton-- it:  35  |Delta|: 0.00958006  alpha:          1  evals:  36  f(y):    5.50751  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  36  A(x):    5.50751  f:    5.42574  g:          0  h:   0.477292  |x-x'|:   0.253062 	stop:DeltaConverge
# ==nlp== it:   2  evals:  36  A(x):    5.71282  mu:25
# --newton-- it:  36  |Delta|:  0.0220933  alpha:          1  evals:  37  f(y):     5.5824  ACCEPT
# --newton-- it:  37  |Delta|:  0.0127036  alpha:          1  evals:  38  f(y):    5.57682  ACCEPT
# --newton-- it:  38  |Delta|:  0.0104725  alpha:          1  evals:  39  f(y):    5.55786  ACCEPT
# --newton-- it:  39  |Delta|:  0.0089167  alpha:          1  evals:  40  f(y):    5.54945  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals:  40  A(x):    5.54945  f:    5.49737  g:          0  h:   0.132612  |x-x'|:  0.0455911 	stop:DeltaConverge
# ==nlp== it:   3  evals:  40  A(x):    5.67156  mu:125
# --newton-- it:  40  |Delta|:  0.0153389  alpha:          1  evals:  41  f(y):    5.58979  ACCEPT
# --newton-- it:  41  |Delta|:  0.0098123  alpha:          1  evals:  42  f(y):    5.66799  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  43  f(y):    5.60081  reject (lineSearch:1)
#                     (line search)        alpha:       0.25  evals:  44  f(y):    5.58872  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   3  evals:  44  A(x):    5.58872  f:    5.55381  g:          0  h:  0.0438836  |x-x'|:  0.0168658 	stop:DeltaConverge
# ==nlp== it:   4  evals:  44  A(x):    5.67942  mu:625
# --newton-- it:  42  |Delta|:  0.0138505  alpha:      0.375  evals:  45  f(y):    5.63542  ACCEPT
# --newton-- it:  43  |Delta|:  0.0120754  alpha:     0.5625  evals:  46  f(y):      5.609  ACCEPT
# --newton-- it:  44  |Delta|:  0.0105138  alpha:    0.84375  evals:  47  f(y):    5.59719  ACCEPT
# --newton-- it:  45  |Delta|: 0.00860983  alpha:          1  evals:  48  f(y):    6.05196  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  49  f(y):    5.70765  reject (lineSearch:1)
#                     (line search)        alpha:       0.25  evals:  50  f(y):    5.62263  reject (lineSearch:2)
#                     (line search)        alpha:      0.125  evals:  51  f(y):    5.60227  reject (lineSearch:3)
#                     (line search)        alpha:     0.0625  evals:  52  f(y):    5.59766  reject (lineSearch:4)
#                     (line search)        alpha:    0.03125  evals:  53  f(y):    5.59687  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   4  evals:  53  A(x):    5.59687  f:    5.57915  g:          0  h:  0.0112599  |x-x'|:  0.0206974 	stop:DeltaConverge
# ==nlp== it:   5  evals:  53  A(x):    5.63534  mu:3125
# --newton-- it:  46  |Delta|: 0.00949308  alpha:   0.046875  evals:  54  f(y):    5.63821  reject (lineSearch:0)
#                     (line search)        alpha:  0.0234375  evals:  55  f(y):    5.63533  reject (lineSearch:1)
#                     (line search)        alpha:  0.0117188  evals:  56  f(y):    5.63495  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   5  evals:  56  A(x):    5.63495  f:    5.57927  g:          0  h:  0.0113564  |x-x'|:0.000111247 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):5.63495

# %%
armed=np.concatenate([take_sword[-1,0:7], take_shield[-1,7:]])
# C.setJointState(path[0,:])
S = ry.Simulation(C, ry.SimulationEngine.physx, verbose=0)

# %%
def simulationCloseGrippers(S, tau=0.01):
    S.closeGripper('l_gripper', width=0.0001, speed=0.5)
    while (not S.getGripperIsGrasping('l_gripper')) and (S.getGripperWidth('l_gripper') > 0.001):
        time.sleep(tau)
        S.step([], tau, ry.ControlMode.none)
        C.view()
    
    S.closeGripper('r_gripper', width=0.0001, speed=0.5)
    while (not S.getGripperIsGrasping('r_gripper')) and (S.getGripperWidth('r_gripper') > 0.001):
        time.sleep(tau)
        S.step([], tau, ry.ControlMode.none)
        C.view()


def simulationOpenGrippers(S, tau=0.01):
    S.openGripper('l_gripper', width=0.05, speed=0.5)
    while S.getGripperWidth('l_gripper') < 0.05 - 0.01:
        time.sleep(tau)
        S.step([], tau, ry.ControlMode.none)
        C.view()
    S.openGripper('r_gripper', width=0.05, speed=0.5)
    while S.getGripperWidth('r_gripper') < 0.05 - 0.01:
        time.sleep(tau)
        S.step([], tau, ry.ControlMode.none)
        C.view()

def simulationGoTo(S, q, tau=0.01, checkCol=False):
    checkColTime = 0.1
    timer = 0
    while np.linalg.norm(S.get_q() - q) > 0.01:
        time.sleep(tau)
        S.step(q, tau, ry.ControlMode.position)
        timer += tau
        C.view()
        if timer > 4:
            print("Target cannot be reached within 4 seconds.")
            break
        if checkCol:
            if timer > checkColTime:
                if findCollision(C, 'sword_1'):
                    return
                else:
                    checkColTime += 0.1

def simulationGoHome(S,tau=0.01):
    checkColTime = 0.1
    timer = 0
    while np.linalg.norm(S.get_q() - q0) > 0.01:
        time.sleep(tau)
        S.step(q0, tau, ry.ControlMode.position)
        C.view()
        timer += tau
        # if timer > checkColTime:
        #     if findCollision(C, 'sword_1'):
        #         break
        #     else:
        #         checkColTime += 0.1
            
def simulationFollowPath(S, path, tau=0.01):
    checkColTime = 0.1
    timer = 0
    for i in range(len(path)):
        while np.linalg.norm(S.get_q() - path[i]) > 0.3:
            time.sleep(tau)
            print(i)
            print(np.linalg.norm(S.get_q() - path[i]))
            S.step(path[i], tau, ry.ControlMode.position)
            C.view()
            timer += tau
            if timer > checkColTime:
                print('check_col')
                if findCollision(C, 'sword_1'):
                    return
                else:
                    checkColTime += 0.1

    simulationGoTo(S,C, path[-1], checkCol=True)

def simulationWait(S, t, tau=0.01):
    for k in range(int(t / tau)):
        time.sleep(tau)
        S.step([], tau, ry.ControlMode.none)
        C.view()

def simulationTorqueCtrl(S, t, torque, tau=0.01):
    for k in range(int(t / tau)):
        time.sleep(tau)
        S.step(torque, tau, ry.ControlMode.acceleration)
        C.view()

def simulationVelocityCtrl(S,t,vel,tau=0.01):
    for k in range(int(t/tau)):
        time.sleep(tau)
        S.step(vel,tau,ry.ControlMode.velocity)
        C.view()

def followInterpolatedPath(S,path,tau=0.01):
    checkColTime = 0.1
    timer = 0
    for i in range(len(path)):
        time.sleep(tau)
        print(i)
        print(np.linalg.norm(S.get_q()- path[i]))
        S.step(path[i],tau,ry.ControlMode.position)
        C.view()
        timer += tau
        if timer > checkColTime:
            if findCollision(C,'sword_1'):
                return
            else:
                checkColTime += 0.1
    simulationGoTo(S,path[-1],checkCol=True)

def findCollision(C,object1):
    collisions = [col for col in C.getCollisions(0) if object1 in col and not col[1].startswith('l_') and not col[0].startswith('l_')]
    if len(collisions) > 0:
        return True
    else:
        return False
    
# Use this code. It is awesome. It will follow the path and stop if there is a collision.    
def followSplinePath(S,path,t,tau=0.01):
    """
        Guides a simulation object along a specified spline path.
        Parameters:
        S (Simulation): The simulation object that will follow the path.
        path (array): A list of waypoints defining the spline path.
        t (float): The total time duration for following the path.
        tau (float, optional): The time step for each simulation step. Default is 0.01.
        The function performs the following steps:
        1. Resets the spline reference of the simulation object.
        2. Sets the spline reference with the given path and a time vector.
        3. Iteratively steps through the simulation, updating the view and checking for collisions.
        4. If a collision with 'sword_1' is detected, the function exits early.
        5. The loop runs for a duration slightly longer than `t` to ensure completion.
        Note:
        - The `+20` in the loop range is a heuristic to prevent early termination when `t` is low.
        - The function checks for collisions every 0.1 seconds.

    """
    checkColTime = 0.1
    timer = 0
    S.resetSplineRef() # Reset previous spline reference
    S.setSplineRef(path,np.linspace(0.01,t,len(path))) # Set new spline reference
    joint_data = np.empty((int(t/tau)+20, 2,S.get_q().shape[0])) # Initialize array to store joint data
    for k in range(int(t/tau)+20): # This +20 is heuristic. It was stopping after a short time when t was low.
        time.sleep(tau)
        S.step([],tau,ry.ControlMode.spline)
        inst_pos = S.get_q().copy()
        inst_vel = S.get_qDot().copy()
        C.view()
        timer += tau
        joint_data[k,0,:] = inst_pos
        joint_data[k,1,:] = inst_vel
        if timer > checkColTime: # Check for collisions every 0.1 seconds
            if findCollision(C,'sword_1'): # Check if sword is colliding with something (left robot is excluded (no self collision))
                return joint_data[:k,:,:] # Return the joint data until collision
            else:
                checkColTime += 0.1 # Increment the collision check time

    return joint_data
    #simulationGoTo(S,path[-1],checkCol=True) 
def initializeSimulation(init_pos):

    S = ry.Simulation(C, ry.SimulationEngine.physx, verbose=0)

    simulationGoTo(S,armed)
    simulationCloseGrippers(S)
    simulationGoTo(S,init_pos)

    shield = C.getFrame('shi')
    robot_base = C.getFrame('r_panda_base')
    sword = C.getFrame('sword_0')
    C.view()
    time.sleep(1)
    return S,shield,robot_base,sword

# %%
def defence_path(robot_pos,sword_pos,shield_pos,C):

    target_pos = np.array([(sword_pos[0]+shield_pos[0])/2,sword_pos[1],sword_pos[2]])

    target = C.addFrame('target', 'world')
    target.setShape(ry.ST.marker, [0.1])
    target.setPosition(target_pos)
    shield_allign = shield_pos - sword_pos
    C.setJointState(robot_pos)
    
    komo = ry.KOMO(C, 1, 10, 2, True)
    # komo.addControlObjective([], 2, 1e1)
    #komo.addControlObjective([], 1, 1e1)
    komo.addObjective([0.,1.], ry.FS.vectorZ, ['shi'], ry.OT.eq, [1e2], shield_allign)
    #komo.addObjective([1.], ry.FS.vectorZ, [shield_allign], ry.OT.eq, [1e2], [0,0,-1])
    komo.addObjective([0.,1.], ry.FS.positionDiff, ['shi', 'target'], ry.OT.eq, [1e2])
    # komo.addObjective([0.,0.95], ry.FS.accumulatedCollisions, [], ry.OT.eq,[1e1])

    ret = ry.NLP_Solver() \
        .setProblem(komo.nlp()) \
        .setOptions( stopTolerance=1e-2) \
        .solve()

    path = komo.getPath()
    C.delFrame('target')
    return path[-1]

# %%
import os 
tau = 0.01
C = ry.Config()
C.addFile("rai-robotModels/scenarios/pandasFight.g")



q0 = C.getJointState()
for file in os.listdir('real_spline_attackPaths'):
    C.setJointState(np.array([ 0.  , -1.  ,  0.  , -2.  ,  0.  ,  2.  ,  0.  ,  0.  ,
    -1.  ,  0.  , -2.  ,  0.  ,  2.  ,  0.]))
    attack_path = np.load('real_spline_attackPaths/'+file)
    init_pos = attack_path[0,0,:]
    S,shield,robot_base,sword = initializeSimulation(init_pos)

    k = 0
    for row_no in range(1,attack_path.shape[0]):
        def_target_pos = defence_path(init_pos,sword.getPosition(),robot_base.getPosition(),C)
        row = attack_path[-1,0,:]
        attacker = row[:7]
        defender = def_target_pos[7:]     
        q = np.concatenate([attacker,defender])   
        S.step(q, tau, ry.ControlMode.position)
        C.view()
        time.sleep(tau)
        print('hey')
        init_pos = q
        print(k)
        k+=1
    del S
# Out:
# -- kin_physx.cpp:addJoint:298(0) ADDING JOINT l_panda_joint7-sword_0 of type rigid with rel [0, 0, 0]
# -- kin_physx.cpp:addJoint:298(0) ADDING JOINT r_panda_joint7-shi of type rigid with rel [0, 0, 0]
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  22  A(x):    589.576  f:          0  g:          0  h:    122.806  |x-x'|:    2.38999 	stop:DeltaConverge
# ==nlp== it:   1  evals:  22  A(x):    4127.03  mu:5
# ==nlp== it:   1  evals:  22  A(x):    4127.03  f:          0  g:          0  h:    122.806  |x-x'|:          0 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   3  A(x):     402.84  f:          0  g:          0  h:    101.835  |x-x'|:   0.054195 	stop:DeltaConverge
# ==nlp== it:   1  evals:   3  A(x):    2819.88  mu:5
# ==nlp== it:   1  evals:   3  A(x):    2819.88  f:          0  g:          0  h:    101.835  |x-x'|:          0 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 1
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   3  A(x):     151.51  f:          0  g:          0  h:    62.8317  |x-x'|:   0.084666 	stop:DeltaConverge
# ==nlp== it:   1  evals:   3  A(x):    1060.57  mu:5
# ==nlp== it:   1  evals:   3  A(x):    1060.57  f:          0  g:          0  h:    62.8317  |x-x'|:          0 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 2
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   3  A(x):     13.196  f:          0  g:          0  h:    18.6352  |x-x'|:    0.08562 	stop:DeltaConverge
# ==nlp== it:   1  evals:   3  A(x):    92.3722  mu:5
# ==nlp== it:   1  evals:   3  A(x):    92.3722  f:          0  g:          0  h:    18.6352  |x-x'|:          0 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 3
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   3  A(x):    32.7983  f:          0  g:          0  h:    29.5439  |x-x'|:   0.101734 	stop:DeltaConverge
# ==nlp== it:   1  evals:   3  A(x):    229.588  mu:5
# ==nlp== it:   1  evals:   3  A(x):    229.588  f:          0  g:          0  h:    29.5439  |x-x'|:          0 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 4
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   3  A(x):    238.282  f:          0  g:          0  h:    80.0497  |x-x'|:  0.0923994 	stop:DeltaConverge
# ==nlp== it:   1  evals:   3  A(x):    1667.97  mu:5
# ==nlp== it:   1  evals:   3  A(x):    1667.97  f:          0  g:          0  h:    80.0497  |x-x'|:          0 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 5
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   3  A(x):    637.452  f:          0  g:          0  h:    131.552  |x-x'|:   0.109301 	stop:DeltaConverge
# ==nlp== it:   1  evals:   3  A(x):    4462.16  mu:5
# ==nlp== it:   1  evals:   3  A(x):    4462.16  f:          0  g:          0  h:    131.552  |x-x'|:          0 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 6
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   3  A(x):    1223.69  f:          0  g:          0  h:    183.107  |x-x'|:   0.100134 	stop:DeltaConverge
# ==nlp== it:   1  evals:   3  A(x):    8565.86  mu:5
# ==nlp== it:   1  evals:   4  A(x):    8565.79  f:          0  g:          0  h:    183.194  |x-x'|: 0.00103253 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 7
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   3  A(x):    1981.15  f:          0  g:          0  h:     233.82  |x-x'|:  0.0929347 	stop:DeltaConverge
# ==nlp== it:   1  evals:   3  A(x):    13868.1  mu:5
# ==nlp== it:   1  evals:   4  A(x):    13867.9  f:          0  g:          0  h:    234.027  |x-x'|:    0.00157 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 8
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   3  A(x):    2888.35  f:          0  g:          0  h:    283.279  |x-x'|:  0.0870144 	stop:DeltaConverge
# ==nlp== it:   1  evals:   3  A(x):    20218.5  mu:5
# ==nlp== it:   1  evals:   4  A(x):      20218  f:          0  g:          0  h:    283.531  |x-x'|: 0.00352208 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 9
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   3  A(x):    3921.01  f:          0  g:          0  h:    331.121  |x-x'|:  0.0881671 	stop:DeltaConverge
# ==nlp== it:   1  evals:   3  A(x):      27447  mu:5
# ==nlp== it:   1  evals:   4  A(x):    27446.5  f:          0  g:          0  h:    331.278  |x-x'|: 0.00373655 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 10
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   4  A(x):    5054.28  f:          0  g:          0  h:    376.885  |x-x'|:  0.0838054 	stop:DeltaConverge
# ==nlp== it:   1  evals:   4  A(x):      35380  mu:5
# ==nlp== it:   1  evals:   5  A(x):    35379.9  f:          0  g:          0  h:    376.965  |x-x'|: 0.00285931 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 11
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  10  A(x):    6263.85  f:          0  g:          0  h:    420.287  |x-x'|:   0.642859 	stop:DeltaConverge
# ==nlp== it:   1  evals:  10  A(x):      43847  mu:5
# ==nlp== it:   1  evals:  11  A(x):    43846.9  f:          0  g:          0  h:    420.331  |x-x'|: 0.00232038 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 12
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   7  A(x):    7526.18  f:          0  g:          0  h:    461.348  |x-x'|:   0.449091 	stop:DeltaConverge
# ==nlp== it:   1  evals:   7  A(x):    52683.3  mu:5
# ==nlp== it:   1  evals:   8  A(x):      52683  f:          0  g:          0  h:    461.236  |x-x'|: 0.00379503 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 13
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  11  A(x):    8846.31  f:          0  g:          0  h:    524.164  |x-x'|:   0.505044 	stop:DeltaConverge
# ==nlp== it:   1  evals:  11  A(x):    61924.2  mu:5
# ==nlp== it:   1  evals:  17  A(x):    61924.2  f:          0  g:          0  h:    524.133  |x-x'|:  0.0245093 	stop:DeltaConverge
# ==nlp== it:   2  evals:  17  A(x):     327314  mu:25
# ==nlp== it:   2  evals:  24  A(x):     327314  f:          0  g:          0  h:    524.134  |x-x'|:  0.0029492 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 14
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  22  A(x):    10227.7  f:          0  g:          0  h:    584.738  |x-x'|:   0.290747 	stop:DeltaConverge
# ==nlp== it:   1  evals:  22  A(x):    71593.6  mu:5
# ==nlp== it:   1  evals:  63  A(x):    71593.5  f:          0  g:          0  h:    584.445  |x-x'|: 0.00551462 	stop:TinyXSteps (bad:1)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 15
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  31  A(x):    11652.2  f:          0  g:          0  h:    642.788  |x-x'|:   0.145802 	stop:DeltaConverge
# ==nlp== it:   1  evals:  31  A(x):    81565.4  mu:5
# ==nlp== it:   1  evals:  77  A(x):    81546.9  f:          0  g:          0  h:    637.868  |x-x'|:  0.0377513 	stop:TinyXSteps (bad:1)
# ==nlp== it:   2  evals:  77  A(x):     431054  mu:25
# ==nlp== it:   2  evals: 273  A(x):     431045  f:          0  g:          0  h:    639.433  |x-x'|:  0.0126974 	stop:TinyXSteps (bad:2)
# ==nlp== it:   3  evals: 273  A(x):2.17854e+06  mu:125
# ==nlp== it:   3  evals: 986  A(x):2.17854e+06  f:          0  g:          0  h:    639.168  |x-x'|: 0.00227597 	stop:TinyXSteps (bad:3)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 16
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  17  A(x):    13095.7  f:          0  g:          0  h:     688.92  |x-x'|:   0.486142 	stop:DeltaConverge
# ==nlp== it:   1  evals:  17  A(x):      91670  mu:5
# ==nlp== it:   1  evals:  58  A(x):    91669.3  f:          0  g:          0  h:     687.79  |x-x'|:  0.0172635 	stop:TinyXSteps (bad:1)
# ==nlp== it:   2  evals:  58  A(x):     484539  mu:25
# ==nlp== it:   2  evals: 210  A(x):     484538  f:          0  g:          0  h:     688.17  |x-x'|: 0.00338515 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 17
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  15  A(x):    14562.8  f:          0  g:          0  h:    735.623  |x-x'|:  0.0901964 	stop:DeltaConverge
# ==nlp== it:   1  evals:  15  A(x):     101940  mu:5
# ==nlp== it:   1  evals:  32  A(x):     101919  f:          0  g:          0  h:    728.576  |x-x'|:    0.15988 	stop:TinyXSteps (bad:1)
# ==nlp== it:   2  evals:  32  A(x):     538743  mu:25
# ==nlp== it:   2  evals: 133  A(x):     538731  f:          0  g:          0  h:    731.236  |x-x'|:  0.0580192 	stop:TinyXSteps (bad:2)
# ==nlp== it:   3  evals: 133  A(x):2.72279e+06  mu:125
# ==nlp== it:   3  evals: 473  A(x):2.72279e+06  f:          0  g:          0  h:    730.595  |x-x'|:  0.0146086 	stop:TinyXSteps (bad:3)
# ==nlp== it:   4  evals: 473  A(x):1.36431e+07  mu:625
# ==nlp== it:   4  evals:1001  A(x):1.36431e+07  f:          0  g:          0  h:    730.736  |x-x'|: 0.00401706 	stop:CritEvals (bad:4)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 18
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  34  A(x):    15932.6  f:          0  g:          0  h:    764.862  |x-x'|:   0.734251 	stop:DeltaConverge
# ==nlp== it:   1  evals:  34  A(x):     111528  mu:5
# ==nlp== it:   1  evals: 301  A(x):     111528  f:          0  g:          0  h:    764.683  |x-x'|:  0.0437429 	stop:TinyXSteps (bad:1)
# ==nlp== it:   2  evals: 301  A(x):     589507  mu:25
# ==nlp== it:   2  evals: 314  A(x):     589507  f:          0  g:          0  h:    764.714  |x-x'|:0.000452075 	stop:LineSearchSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 19
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals: 173  A(x):    16972.1  f:          0  g:          0  h:    775.617  |x-x'|:    1.77039 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals: 173  A(x):     118804  mu:5
# ==nlp== it:   1  evals: 178  A(x):     118804  f:          0  g:          0  h:     775.62  |x-x'|:0.000131755 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 20
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  56  A(x):    17870.9  f:          0  g:          0  h:    784.657  |x-x'|:    2.28993 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  56  A(x):     125096  mu:5
# ==nlp== it:   1  evals:  66  A(x):     125096  f:          0  g:          0  h:    784.657  |x-x'|:2.16839e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 21
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  29  A(x):    18767.9  f:          0  g:          0  h:    797.027  |x-x'|:   0.880863 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  29  A(x):     131375  mu:5
# ==nlp== it:   1  evals:  37  A(x):     131375  f:          0  g:          0  h:    797.027  |x-x'|:3.11926e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 22
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  46  A(x):    19591.3  f:          0  g:          0  h:    805.636  |x-x'|:   0.404562 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  46  A(x):     137139  mu:5
# ==nlp== it:   1  evals:  57  A(x):     137139  f:          0  g:          0  h:    805.636  |x-x'|:2.11292e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 23
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  42  A(x):      20410  f:          0  g:          0  h:    814.767  |x-x'|:  0.0927821 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  42  A(x):     142870  mu:5
# ==nlp== it:   1  evals:  72  A(x):     142870  f:          0  g:          0  h:    814.768  |x-x'|:1.89314e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 24
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  34  A(x):    20984.9  f:          0  g:          0  h:    819.517  |x-x'|:   0.296039 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  34  A(x):     146894  mu:5
# ==nlp== it:   1  evals:  44  A(x):     146894  f:          0  g:          0  h:    819.517  |x-x'|:3.16883e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 25
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  42  A(x):    21611.6  f:          0  g:          0  h:    825.715  |x-x'|:   0.412219 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  42  A(x):     151281  mu:5
# ==nlp== it:   1  evals:  57  A(x):     151281  f:          0  g:          0  h:    825.715  |x-x'|:2.02511e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 26
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  41  A(x):      22123  f:          0  g:          0  h:    820.224  |x-x'|:  0.0650396 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  41  A(x):     154861  mu:5
# ==nlp== it:   1  evals:  74  A(x):     154664  f:          0  g:          0  h:    832.731  |x-x'|:    1.33507 	stop:TinyXSteps (bad:2)
# ==nlp== it:   2  evals:  74  A(x):     817751  mu:25
# ==nlp== it:   2  evals: 190  A(x):     817625  f:          0  g:          0  h:    828.494  |x-x'|:    0.04768 	stop:TinyXSteps (bad:3)
# ==nlp== it:   3  evals: 190  A(x):4.13254e+06  mu:125
# ==nlp== it:   3  evals: 655  A(x):4.13247e+06  f:          0  g:          0  h:    829.341  |x-x'|:   0.017732 	stop:TinyXSteps (bad:4)
# ==nlp== it:   4  evals: 655  A(x):2.07068e+07  mu:625
# ==nlp== it:   4  evals:1001  A(x):2.07067e+07  f:          0  g:          0  h:    829.182  |x-x'|: 0.00692023 	stop:CritEvals (bad:5)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 27
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  31  A(x):    22521.2  f:          0  g:          0  h:     831.34  |x-x'|:   0.808534 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  31  A(x):     157649  mu:5
# ==nlp== it:   1  evals:  52  A(x):     157649  f:          0  g:          0  h:    831.337  |x-x'|:5.08351e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 28
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  26  A(x):    22879.6  f:          0  g:          0  h:     833.32  |x-x'|:   0.677667 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  26  A(x):     160157  mu:5
# ==nlp== it:   1  evals:  43  A(x):     160157  f:          0  g:          0  h:    833.321  |x-x'|:3.21013e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 29
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  28  A(x):    23159.3  f:          0  g:          0  h:    834.127  |x-x'|:    1.44309 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  28  A(x):     162115  mu:5
# ==nlp== it:   1  evals:  55  A(x):     162115  f:          0  g:          0  h:    834.129  |x-x'|:5.21648e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 30
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  30  A(x):    23118.2  f:          0  g:          0  h:     830.85  |x-x'|:   0.054074 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  30  A(x):     161828  mu:5
# ==nlp== it:   1  evals:  53  A(x):     161828  f:          0  g:          0  h:    830.852  |x-x'|:6.93793e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 31
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  38  A(x):    23183.8  f:          0  g:          0  h:    829.438  |x-x'|:   0.657593 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  38  A(x):     162287  mu:5
# ==nlp== it:   1  evals:  47  A(x):     162287  f:          0  g:          0  h:    829.438  |x-x'|:0.000169018 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 32
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  49  A(x):    23325.8  f:          0  g:          0  h:    829.049  |x-x'|:    1.02801 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  49  A(x):     163281  mu:5
# ==nlp== it:   1  evals:  65  A(x):     163281  f:          0  g:          0  h:    829.049  |x-x'|:0.000326283 	stop:LineSearchSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 33
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  29  A(x):    23457.6  f:          0  g:          0  h:    828.729  |x-x'|:   0.141078 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  29  A(x):     164203  mu:5
# ==nlp== it:   1  evals:  50  A(x):     164203  f:          0  g:          0  h:    828.729  |x-x'|:0.000130194 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 34
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  96  A(x):    23611.9  f:          0  g:          0  h:    829.467  |x-x'|:    1.27771 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  96  A(x):     165283  mu:5
# ==nlp== it:   1  evals: 106  A(x):     165283  f:          0  g:          0  h:    829.467  |x-x'|: 0.00304112 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 35
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  68  A(x):    23754.7  f:          0  g:          0  h:    830.198  |x-x'|:     2.1801 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  68  A(x):     166283  mu:5
# ==nlp== it:   1  evals:  84  A(x):     166283  f:          0  g:          0  h:    830.198  |x-x'|:0.000614423 	stop:LineSearchSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 36
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  30  A(x):    23884.9  f:          0  g:          0  h:    830.442  |x-x'|:    2.20044 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  30  A(x):     167194  mu:5
# ==nlp== it:   1  evals:  62  A(x):     167194  f:          0  g:          0  h:    830.441  |x-x'|:6.43025e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 37
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  58  A(x):    24012.4  f:          0  g:          0  h:    832.754  |x-x'|:    1.88679 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  58  A(x):     168087  mu:5
# ==nlp== it:   1  evals:  63  A(x):     168087  f:          0  g:          0  h:    832.754  |x-x'|:4.83602e-06 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 38
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  30  A(x):    24089.4  f:          0  g:          0  h:    833.704  |x-x'|:  0.0203996 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  30  A(x):     168626  mu:5
# ==nlp== it:   1  evals:  35  A(x):     168626  f:          0  g:          0  h:    833.704  |x-x'|:4.37559e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 39
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  33  A(x):    24151.9  f:          0  g:          0  h:    834.986  |x-x'|:  0.0313048 	stop:DeltaConverge
# ==nlp== it:   1  evals:  33  A(x):     169063  mu:5
# ==nlp== it:   1  evals:  42  A(x):     169063  f:          0  g:          0  h:    835.002  |x-x'|: 0.00098544 	stop:TinyXSteps (bad:1)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 40
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  27  A(x):    24182.4  f:          0  g:          0  h:    835.876  |x-x'|:  0.0291368 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  27  A(x):     169277  mu:5
# ==nlp== it:   1  evals:  32  A(x):     169277  f:          0  g:          0  h:    835.876  |x-x'|:4.38713e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 41
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  32  A(x):    24218.8  f:          0  g:          0  h:    821.143  |x-x'|:  0.0546579 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  32  A(x):     169532  mu:5
# ==nlp== it:   1  evals:  68  A(x):     169222  f:          0  g:          0  h:    842.646  |x-x'|:  0.0704668 	stop:TinyXSteps (bad:2)
# ==nlp== it:   2  evals:  68  A(x):     894966  mu:25
# ==nlp== it:   2  evals: 148  A(x):     894704  f:          0  g:          0  h:    835.228  |x-x'|:   0.043665 	stop:TinyXSteps (bad:3)
# ==nlp== it:   3  evals: 148  A(x):4.52235e+06  mu:125
# ==nlp== it:   3  evals: 239  A(x):4.52224e+06  f:          0  g:          0  h:    836.442  |x-x'|:  0.0127011 	stop:TinyXSteps (bad:4)
# ==nlp== it:   4  evals: 239  A(x):2.26599e+07  mu:625
# ==nlp== it:   4  evals: 244  A(x):2.26599e+07  f:          0  g:          0  h:    836.446  |x-x'|:6.74777e-05 	stop:TinyXSteps (bad:5)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 42
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  41  A(x):    24450.4  f:          0  g:          0  h:     825.67  |x-x'|:  0.0510084 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  41  A(x):     171153  mu:5
# ==nlp== it:   1  evals:  81  A(x):     170824  f:          0  g:          0  h:    847.652  |x-x'|:   0.104792 	stop:TinyXSteps (bad:2)
# ==nlp== it:   2  evals:  81  A(x):     903442  mu:25
# ==nlp== it:   2  evals: 170  A(x):     903181  f:          0  g:          0  h:    840.439  |x-x'|:  0.0384572 	stop:TinyXSteps (bad:3)
# ==nlp== it:   3  evals: 170  A(x):4.56518e+06  mu:125
# ==nlp== it:   3  evals: 223  A(x):4.56511e+06  f:          0  g:          0  h:    841.137  |x-x'|: 0.00623954 	stop:TinyXSteps (bad:4)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 43
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  35  A(x):    24354.5  f:          0  g:          0  h:    842.103  |x-x'|:  0.0291727 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  35  A(x):     170482  mu:5
# ==nlp== it:   1  evals:  40  A(x):     170482  f:          0  g:          0  h:    842.103  |x-x'|:1.74171e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 44
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  22  A(x):    23888.7  f:          0  g:          0  h:    835.469  |x-x'|:  0.0552263 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  22  A(x):     167221  mu:5
# ==nlp== it:   1  evals:  27  A(x):     167221  f:          0  g:          0  h:    835.469  |x-x'|:2.93089e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 45
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  37  A(x):    24140.7  f:          0  g:          0  h:    841.102  |x-x'|:  0.0311913 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  37  A(x):     168985  mu:5
# ==nlp== it:   1  evals:  42  A(x):     168985  f:          0  g:          0  h:    841.101  |x-x'|: 2.6187e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 46
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:  26  A(x):    24075.1  f:          0  g:          0  h:    823.103  |x-x'|:  0.0739433 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  26  A(x):     168526  mu:5
# ==nlp== it:   1  evals:  83  A(x):     168219  f:          0  g:          0  h:    847.974  |x-x'|:  0.0709656 	stop:TinyXSteps (bad:2)
# ==nlp== it:   2  evals:  83  A(x):     889635  mu:25
# ==nlp== it:   2  evals: 215  A(x):     889395  f:          0  g:          0  h:    839.746  |x-x'|:  0.0405378 	stop:TinyXSteps (bad:3)
# ==nlp== it:   3  evals: 215  A(x):4.49544e+06  mu:125
# ==nlp== it:   3  evals: 220  A(x):4.49544e+06  f:          0  g:          0  h:    839.808  |x-x'|:0.000360952 	stop:TinyXSteps (bad:4)
# ==nlp== StoppingCriterion Delta<0.01
# hey
# 47
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
