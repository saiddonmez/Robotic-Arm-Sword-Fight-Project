# %%
import robotic as ry
import time
import numpy as np
import os
import time
import matplotlib.pyplot as plt
C = ry.Config()
C.addFile("rai-robotModels/scenarios/pandasFight.g")

C.setJointState(np.array([ 0.  , -1.  ,  0.  , -2.  ,  0.  ,  2.  ,  0.  ,  0.  ,
       -1.  ,  0.  , -2.  ,  0.  ,  2.  ,  0.]))
q0 = C.getJointState()
C.view()
# Out:
# 0

# %%
komo = ry.KOMO(C, 10, 10, 2, True)
komo.addControlObjective([], 0, 1e-1) 
komo.addControlObjective([], 2, 1e0)
komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq,[1e1])
komo.addObjective([5,10], ry.FS.positionDiff, ['r_gripper', "shi-h1"], ry.OT.eq, [1e1])
komo.addObjective([5.,10.], ry.FS.scalarProductZZ, ['r_gripper', 'shi-h1'], ry.OT.eq, [1e1], [])
komo.addObjective([5.,10.], ry.FS.scalarProductXZ, ['shi-h1','r_gripper'], ry.OT.eq, [1e1], [])
komo.addObjective([5.,10.], ry.FS.scalarProductXZ, ['r_gripper','shi-h1'], ry.OT.eq, [1e1], [])

# komo.addObjective([3,5], ry.FS.position,['l_gripper'], ry.OT.eq, [1e1], grasp_pos + np.array([0, 0, 0.5]) )

# komo.addObjective([5,10], ry.FS.position,['l_gripper'], ry.OT.eq, [1e1], grasp_pos )
# komo.addObjective([5,10], ry.FS.vectorX, ['l_gripper'], ry.OT.eq, [1e1],normal)

ret = ry.NLP_Solver() \
.setProblem(komo.nlp()) \
.setOptions( stopTolerance=1e-2, verbose=4 ) \
.solve()

take_shield = komo.getPath()
# Out:
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):12133.5 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):     9427.2  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    7039.78  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    5080.29  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):    3548.65  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    2467.87  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):    1637.22  ACCEPT
# --newton-- it:   7  |Delta|:        0.2  alpha:          1  evals:   8  f(y):    980.115  ACCEPT
# --newton-- it:   8  |Delta|:        0.2  alpha:          1  evals:   9  f(y):    482.727  ACCEPT
# --newton-- it:   9  |Delta|:        0.2  alpha:          1  evals:  10  f(y):    169.873  ACCEPT
# --newton-- it:  10  |Delta|:        0.2  alpha:          1  evals:  11  f(y):    38.8635  ACCEPT
# --newton-- it:  11  |Delta|:        0.2  alpha:          1  evals:  12  f(y):    20.6189  ACCEPT
# --newton-- it:  12  |Delta|:    0.13741  alpha:          1  evals:  13  f(y):    8.69644  ACCEPT
# --newton-- it:  13  |Delta|:  0.0991466  alpha:          1  evals:  14  f(y):    8.10654  ACCEPT
# --newton-- it:  14  |Delta|:  0.0784913  alpha:          1  evals:  15  f(y):    7.75915  ACCEPT
# --newton-- it:  15  |Delta|:  0.0656077  alpha:          1  evals:  16  f(y):    7.50778  ACCEPT
# --newton-- it:  16  |Delta|:  0.0563804  alpha:          1  evals:  17  f(y):    7.31687  ACCEPT
# --newton-- it:  17  |Delta|:  0.0490998  alpha:          1  evals:  18  f(y):    7.16883  ACCEPT
# --newton-- it:  18  |Delta|:  0.0429596  alpha:          1  evals:  19  f(y):    7.05272  ACCEPT
# --newton-- it:  19  |Delta|:  0.0376862  alpha:          1  evals:  20  f(y):    6.96094  ACCEPT
# --newton-- it:  20  |Delta|:  0.0330776  alpha:          1  evals:  21  f(y):    6.88788  ACCEPT
# --newton-- it:  21  |Delta|:  0.0290467  alpha:          1  evals:  22  f(y):    6.82927  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:  22  A(x):    6.82927  f:    6.08319  g:          0  h:    8.64424  |x-x'|:    1.88807 	stop:DeltaConverge
# ==nlp== it:   1  evals:  22  A(x):    11.3057  mu:5
# --newton-- it:  22  |Delta|:  0.0554424  alpha:          1  evals:  23  f(y):    11.0296  ACCEPT
# --newton-- it:  23  |Delta|:  0.0349614  alpha:          1  evals:  24  f(y):    10.5665  ACCEPT
# --newton-- it:  24  |Delta|:  0.0285891  alpha:          1  evals:  25  f(y):    10.5024  ACCEPT
# --newton-- it:  25  |Delta|:  0.0240843  alpha:          1  evals:  26  f(y):    10.4619  ACCEPT
# --newton-- it:  26  |Delta|:  0.0206944  alpha:          1  evals:  27  f(y):    10.4306  ACCEPT
# --newton-- it:  27  |Delta|:   0.017919  alpha:          1  evals:  28  f(y):     10.404  ACCEPT
# --newton-- it:  28  |Delta|:  0.0155767  alpha:          1  evals:  29  f(y):    10.3832  ACCEPT
# --newton-- it:  29  |Delta|:   0.013555  alpha:          1  evals:  30  f(y):    10.3647  ACCEPT
# --newton-- it:  30  |Delta|:  0.0118054  alpha:          1  evals:  31  f(y):      10.35  ACCEPT
# --newton-- it:  31  |Delta|:   0.010279  alpha:          1  evals:  32  f(y):    10.3364  ACCEPT
# --newton-- it:  32  |Delta|:  0.0089465  alpha:          1  evals:  33  f(y):    10.3256  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  33  A(x):    10.3256  f:    6.07824  g:          0  h:     7.3796  |x-x'|:   0.214171 	stop:DeltaConverge
# ==nlp== it:   2  evals:  33  A(x):    28.3061  mu:25
# --newton-- it:  33  |Delta|:  0.0201683  alpha:          1  evals:  34  f(y):    28.2642  ACCEPT
# --newton-- it:  34  |Delta|: 0.00993494  alpha:          1  evals:  35  f(y):    28.1664  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals:  35  A(x):    28.1664  f:    6.12575  g:          0  h:    7.13247  |x-x'|:  0.0234187 	stop:DeltaConverge
# ==nlp== it:   3  evals:  35  A(x):    117.263  mu:125
# --newton-- it:  35  |Delta|: 0.00836172  alpha:          1  evals:  36  f(y):    117.238  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   3  evals:  36  A(x):    117.238  f:    6.14883  g:          0  h:    7.12694  |x-x'|: 0.00836172 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):117.238

# %%
komo = ry.KOMO(C, 10, 10, 2, True)
komo.addControlObjective([], 0, 1e-1) 
komo.addControlObjective([], 2, 1e0)
komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq,[1e1])
komo.addObjective([5,10], ry.FS.positionDiff, ['l_gripper', "sword_0"], ry.OT.eq, [1e1])
komo.addObjective([5.,10.], ry.FS.scalarProductYZ, ['sword_0','l_gripper'], ry.OT.eq, [1e1], [])
komo.addObjective([5.,10.], ry.FS.scalarProductXZ, ['sword_0','l_gripper'], ry.OT.eq, [1e1], [])
komo.addObjective([5.,10.], ry.FS.scalarProductXX, ['l_gripper','sword_0'], ry.OT.eq, [1e1], [])

# komo.addObjective([3,5], ry.FS.position,['l_gripper'], ry.OT.eq, [1e1], grasp_pos + np.array([0, 0, 0.5]) )

# komo.addObjective([5,10], ry.FS.position,['l_gripper'], ry.OT.eq, [1e1], grasp_pos )
# komo.addObjective([5,10], ry.FS.vectorX, ['l_gripper'], ry.OT.eq, [1e1],normal)

ret = ry.NLP_Solver() \
.setProblem(komo.nlp()) \
.setOptions( stopTolerance=1e-2, verbose=4 ) \
.solve()

take_sword= komo.getPath()
# Out:
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):11392 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    8811.41  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    6700.83  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    4841.77  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):    3200.89  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    2093.78  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):    1364.68  ACCEPT
# --newton-- it:   7  |Delta|:        0.2  alpha:          1  evals:   8  f(y):    851.123  ACCEPT
# --newton-- it:   8  |Delta|:        0.2  alpha:          1  evals:   9  f(y):    459.243  ACCEPT
# --newton-- it:   9  |Delta|:        0.2  alpha:          1  evals:  10  f(y):    212.427  ACCEPT
# --newton-- it:  10  |Delta|:        0.2  alpha:          1  evals:  11  f(y):    83.2659  ACCEPT
# --newton-- it:  11  |Delta|:        0.2  alpha:          1  evals:  12  f(y):    37.4745  ACCEPT
# --newton-- it:  12  |Delta|:        0.2  alpha:          1  evals:  13  f(y):    15.0349  ACCEPT
# --newton-- it:  13  |Delta|:    0.16686  alpha:          1  evals:  14  f(y):    7.74912  ACCEPT
# --newton-- it:  14  |Delta|:   0.115261  alpha:          1  evals:  15  f(y):    6.71301  ACCEPT
# --newton-- it:  15  |Delta|:  0.0886818  alpha:          1  evals:  16  f(y):    6.35452  ACCEPT
# --newton-- it:  16  |Delta|:  0.0721278  alpha:          1  evals:  17  f(y):    6.12903  ACCEPT
# --newton-- it:  17  |Delta|:  0.0611066  alpha:          1  evals:  18  f(y):    5.96649  ACCEPT
# --newton-- it:  18  |Delta|:  0.0530723  alpha:          1  evals:  19  f(y):     5.8422  ACCEPT
# --newton-- it:  19  |Delta|:   0.046698  alpha:          1  evals:  20  f(y):    5.74424  ACCEPT
# --newton-- it:  20  |Delta|:  0.0412939  alpha:          1  evals:  21  f(y):     5.6657  ACCEPT
# --newton-- it:  21  |Delta|:  0.0366386  alpha:          1  evals:  22  f(y):    5.60207  ACCEPT
# --newton-- it:  22  |Delta|:  0.0325042  alpha:          1  evals:  23  f(y):    5.55011  ACCEPT
# --newton-- it:  23  |Delta|:  0.0288379  alpha:          1  evals:  24  f(y):    5.50737  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:  24  A(x):    5.50737  f:    5.31823  g:          0  h:    2.43362  |x-x'|:    2.03662 	stop:DeltaConverge
# ==nlp== it:   1  evals:  24  A(x):    6.64222  mu:5
# --newton-- it:  24  |Delta|:  0.0720077  alpha:          1  evals:  25  f(y):    5.84451  ACCEPT
# --newton-- it:  25  |Delta|:  0.0404348  alpha:          1  evals:  26  f(y):    5.74843  ACCEPT
# --newton-- it:  26  |Delta|:  0.0329606  alpha:          1  evals:  27  f(y):    5.69438  ACCEPT
# --newton-- it:  27  |Delta|:  0.0280476  alpha:          1  evals:  28  f(y):    5.65341  ACCEPT
# --newton-- it:  28  |Delta|:  0.0242615  alpha:          1  evals:  29  f(y):    5.62099  ACCEPT
# --newton-- it:  29  |Delta|:  0.0209871  alpha:          1  evals:  30  f(y):    5.59503  ACCEPT
# --newton-- it:  30  |Delta|:   0.018361  alpha:          1  evals:  31  f(y):    5.57356  ACCEPT
# --newton-- it:  31  |Delta|:  0.0161522  alpha:          1  evals:  32  f(y):    5.55574  ACCEPT
# --newton-- it:  32  |Delta|:  0.0141779  alpha:          1  evals:  33  f(y):    5.54076  ACCEPT
# --newton-- it:  33  |Delta|:  0.0124436  alpha:          1  evals:  34  f(y):    5.52801  ACCEPT
# --newton-- it:  34  |Delta|:    0.01092  alpha:          1  evals:  35  f(y):    5.51705  ACCEPT
# --newton-- it:  35  |Delta|: 0.00958006  alpha:          1  evals:  36  f(y):    5.50751  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  36  A(x):    5.50751  f:    5.42574  g:          0  h:   0.477292  |x-x'|:   0.253062 	stop:DeltaConverge
# ==nlp== it:   2  evals:  36  A(x):    5.71282  mu:25
# --newton-- it:  36  |Delta|:  0.0220933  alpha:          1  evals:  37  f(y):     5.5824  ACCEPT
# --newton-- it:  37  |Delta|:  0.0127036  alpha:          1  evals:  38  f(y):    5.57682  ACCEPT
# --newton-- it:  38  |Delta|:  0.0104725  alpha:          1  evals:  39  f(y):    5.55786  ACCEPT
# --newton-- it:  39  |Delta|:  0.0089167  alpha:          1  evals:  40  f(y):    5.54945  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals:  40  A(x):    5.54945  f:    5.49737  g:          0  h:   0.132612  |x-x'|:  0.0455911 	stop:DeltaConverge
# ==nlp== it:   3  evals:  40  A(x):    5.67156  mu:125
# --newton-- it:  40  |Delta|:  0.0153389  alpha:          1  evals:  41  f(y):    5.58979  ACCEPT
# --newton-- it:  41  |Delta|:  0.0098123  alpha:          1  evals:  42  f(y):    5.66799  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  43  f(y):    5.60081  reject (lineSearch:1)
#                     (line search)        alpha:       0.25  evals:  44  f(y):    5.58872  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   3  evals:  44  A(x):    5.58872  f:    5.55381  g:          0  h:  0.0438836  |x-x'|:  0.0168658 	stop:DeltaConverge
# ==nlp== it:   4  evals:  44  A(x):    5.67942  mu:625
# --newton-- it:  42  |Delta|:  0.0138505  alpha:      0.375  evals:  45  f(y):    5.63542  ACCEPT
# --newton-- it:  43  |Delta|:  0.0120754  alpha:     0.5625  evals:  46  f(y):      5.609  ACCEPT
# --newton-- it:  44  |Delta|:  0.0105138  alpha:    0.84375  evals:  47  f(y):    5.59719  ACCEPT
# --newton-- it:  45  |Delta|: 0.00860983  alpha:          1  evals:  48  f(y):    6.05196  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  49  f(y):    5.70765  reject (lineSearch:1)
#                     (line search)        alpha:       0.25  evals:  50  f(y):    5.62263  reject (lineSearch:2)
#                     (line search)        alpha:      0.125  evals:  51  f(y):    5.60227  reject (lineSearch:3)
#                     (line search)        alpha:     0.0625  evals:  52  f(y):    5.59766  reject (lineSearch:4)
#                     (line search)        alpha:    0.03125  evals:  53  f(y):    5.59687  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   4  evals:  53  A(x):    5.59687  f:    5.57915  g:          0  h:  0.0112599  |x-x'|:  0.0206974 	stop:DeltaConverge
# ==nlp== it:   5  evals:  53  A(x):    5.63534  mu:3125
# --newton-- it:  46  |Delta|: 0.00949308  alpha:   0.046875  evals:  54  f(y):    5.63821  reject (lineSearch:0)
#                     (line search)        alpha:  0.0234375  evals:  55  f(y):    5.63533  reject (lineSearch:1)
#                     (line search)        alpha:  0.0117188  evals:  56  f(y):    5.63495  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   5  evals:  56  A(x):    5.63495  f:    5.57927  g:          0  h:  0.0113564  |x-x'|:0.000111247 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):5.63495

# %%
armed=np.concatenate([take_sword[-1,0:7], take_shield[-1,7:]])
# C.setJointState(path[0,:])
S = ry.Simulation(C, ry.SimulationEngine.physx, verbose=0)

# %%
def simulationCloseGrippers(S, tau=0.01):
    S.closeGripper('l_gripper', width=0.0001, speed=0.5)
    while (not S.getGripperIsGrasping('l_gripper')) and (S.getGripperWidth('l_gripper') > 0.001):
        time.sleep(tau)
        S.step([], tau, ry.ControlMode.none)
        #C.view()
    
    S.closeGripper('r_gripper', width=0.0001, speed=0.5)
    while (not S.getGripperIsGrasping('r_gripper')) and (S.getGripperWidth('r_gripper') > 0.001):
        time.sleep(tau)
        S.step([], tau, ry.ControlMode.none)
        #C.view()


def simulationOpenGrippers(S, tau=0.01):
    S.openGripper('l_gripper', width=0.05, speed=0.5)
    while S.getGripperWidth('l_gripper') < 0.05 - 0.01:
        time.sleep(tau)
        S.step([], tau, ry.ControlMode.none)
        #C.view()
    S.openGripper('r_gripper', width=0.05, speed=0.5)
    while S.getGripperWidth('r_gripper') < 0.05 - 0.01:
        time.sleep(tau)
        S.step([], tau, ry.ControlMode.none)
        #C.view()

def simulationGoTo(S, q, tau=0.01, checkCol=False):
    checkColTime = 0.1
    timer = 0
    while np.linalg.norm(S.get_q() - q) > 0.01:
        time.sleep(tau)
        S.step(q, tau, ry.ControlMode.position)
        timer += tau
        #C.view()
        if timer > 4:
            print("Target cannot be reached within 4 seconds.")
            break
        if checkCol:
            if timer > checkColTime:
                if findCollision(C, 'sword_1'):
                    return
                else:
                    checkColTime += 0.1

def simulationGoHome(S,tau=0.01):
    checkColTime = 0.1
    timer = 0
    while np.linalg.norm(S.get_q() - q0) > 0.01:
        time.sleep(tau)
        S.step(q0, tau, ry.ControlMode.position)
        #C.view()
        timer += tau
        # if timer > checkColTime:
        #     if findCollision(C, 'sword_1'):
        #         break
        #     else:
        #         checkColTime += 0.1
            
def simulationFollowPath(S, path, tau=0.01):
    checkColTime = 0.1
    timer = 0
    for i in range(len(path)):
        while np.linalg.norm(S.get_q() - path[i]) > 0.3:
            time.sleep(tau)
            print(i)
            print(np.linalg.norm(S.get_q() - path[i]))
            S.step(path[i], tau, ry.ControlMode.position)
            #C.view()
            timer += tau
            if timer > checkColTime:
                print('check_col')
                if findCollision(C, 'sword_1'):
                    return
                else:
                    checkColTime += 0.1

    simulationGoTo(S,C, path[-1], checkCol=True)

def simulationWait(S, t, tau=0.01):
    for k in range(int(t / tau)):
        time.sleep(tau)
        S.step([], tau, ry.ControlMode.none)
        #C.view()

def simulationTorqueCtrl(S, t, torque, tau=0.01):
    for k in range(int(t / tau)):
        time.sleep(tau)
        S.step(torque, tau, ry.ControlMode.acceleration)
        #C.view()

def simulationVelocityCtrl(S,t,vel,tau=0.01):
    for k in range(int(t/tau)):
        time.sleep(tau)
        S.step(vel,tau,ry.ControlMode.velocity)
        #C.view()

def followInterpolatedPath(S,path,tau=0.01):
    checkColTime = 0.1
    timer = 0
    for i in range(len(path)):
        time.sleep(tau)
        print(i)
        print(np.linalg.norm(S.get_q()- path[i]))
        S.step(path[i],tau,ry.ControlMode.position)
        #C.view()
        timer += tau
        if timer > checkColTime:
            if findCollision(C,'sword_1'):
                return
            else:
                checkColTime += 0.1
    simulationGoTo(S,path[-1],checkCol=True)

def findCollision(C,object1):
    collisions = [col for col in C.getCollisions(0) if object1 in col and not col[1].startswith('l_') and not col[0].startswith('l_')]
    if len(collisions) > 0:
        return True
    else:
        return False
    
def findCollisionshield(C):
    collisions = [col for col in C.getCollisions(0) if 'shi' in col and 'sword_1' in col]
    if len(collisions) > 0:
        return True
    else:
        return False
    
def findCollisionsword(C):
    collisions = [col for col in C.getCollisions(0) if 'sword_1' in col ]
    if len(collisions) > 0:
        return True
    else:
        return False
# Use this code. It is awesome. It will follow the path and stop if there is a collision.    
def followSplinePath(S,path,t,tau=0.01):
    """
        Guides a simulation object along a specified spline path.
        Parameters:
        S (Simulation): The simulation object that will follow the path.
        path (array): A list of waypoints defining the spline path.
        t (float): The total time duration for following the path.
        tau (float, optional): The time step for each simulation step. Default is 0.01.
        The function performs the following steps:
        1. Resets the spline reference of the simulation object.
        2. Sets the spline reference with the given path and a time vector.
        3. Iteratively steps through the simulation, updating the view and checking for collisions.
        4. If a collision with 'sword_1' is detected, the function exits early.
        5. The loop runs for a duration slightly longer than `t` to ensure completion.
        Note:
        - The `+20` in the loop range is a heuristic to prevent early termination when `t` is low.
        - The function checks for collisions every 0.1 seconds.

    """
    checkColTime = 0.1
    timer = 0
    S.resetSplineRef() # Reset previous spline reference
    S.setSplineRef(path,np.linspace(0.01,t,len(path))) # Set new spline reference
    joint_data = np.empty((int(t/tau)+20, 2,S.get_q().shape[0])) # Initialize array to store joint data
    for k in range(int(t/tau)+20): # This +20 is heuristic. It was stopping after a short time when t was low.
        time.sleep(tau)
        S.step([],tau,ry.ControlMode.spline)
        inst_pos = S.get_q().copy()
        inst_vel = S.get_qDot().copy()
        C.view()
        timer += tau
        joint_data[k,0,:] = inst_pos
        joint_data[k,1,:] = inst_vel
        if timer > checkColTime: # Check for collisions every 0.1 seconds
            if findCollision(C,'sword_1'): # Check if sword is colliding with something (left robot is excluded (no self collision))
                return joint_data[:k,:,:] # Return the joint data until collision
            else:
                checkColTime += 0.1 # Increment the collision check time

    return joint_data
    #simulationGoTo(S,path[-1],checkCol=True) 
def initializeSimulation(init_pos):

    S = ry.Simulation(C, ry.SimulationEngine.physx, verbose=0)

    simulationGoTo(S,armed)
    simulationCloseGrippers(S)
    simulationGoTo(S,init_pos)

    shield = C.getFrame('shi')
    robot_base = C.getFrame('r_panda_base')
    sword = C.getFrame('sword_1')
    # C.view()
    return S,shield,robot_base,sword

# %%
def defence_path(robot_pos,sword_pos,shield_pos,hitting_point,C):

    target_pos = np.array([(sword_pos[0]+hitting_point[0])/2,(sword_pos[1]+hitting_point[1])/2,(sword_pos[2]+hitting_point[2])/2])

    target = C.addFrame('target', 'world')
    target.setShape(ry.ST.marker, [0.1])
    target.setPosition(target_pos)
    shield_allign = shield_pos - sword_pos
    C.setJointState(robot_pos)
    
    komo = ry.KOMO(C, 1, 10, 2, True)
    komo.addControlObjective([], 2, 1e1)
    komo.addControlObjective([], 0, 1e1)
    komo.addObjective([0.,1.], ry.FS.vectorZ, ['shi'], ry.OT.eq, [1e1], shield_allign)
    #komo.addObjective([1.], ry.FS.vectorZ, [shield_allign], ry.OT.eq, [1e2], [0,0,-1])
    komo.addObjective([0.,1.], ry.FS.positionDiff, ['shi', 'target'], ry.OT.eq, [1e2])
    # komo.addObjective([0.,0.95], ry.FS.accumulatedCollisions, [], ry.OT.eq,[1e1])

    ret = ry.NLP_Solver() \
        .setProblem(komo.nlp()) \
        .setOptions( stopTolerance=1e-2) \
        .solve()

    path = komo.getPath()
    C.delFrame('target')
    return path[8]

# %%
import scipy
def interpolate_path(path,N):
    cubic_spline_interpolator = scipy.interpolate.CubicSpline(np.arange(path.shape[0]), path, axis = 0) 
    interp_path = cubic_spline_interpolator(np.linspace(0,path.shape[0]-1,N))

    return interp_path

# %%
import os 
tau = 0.01


for file in os.listdir('real_spline_attackPaths'):

    C = ry.Config()
    C.addFile("rai-robotModels/scenarios/pandasFight.g")
    q0 = C.getJointState()
    C.setJointState(np.array([ 0.  , -1.  ,  0.  , -2.  ,  0.  ,  2.  ,  0.  ,  0.  ,
    -1.  ,  0.  , -2.  ,  0.  ,  2.  ,  0.]))
    attack_path = np.load('real_spline_attackPaths/'+file)
    len_attack = attack_path.shape[0]
    if len_attack > 17:
        hiting_point = np.load('attackPaths/hitting_point_'+file[-5:])
        init_pos = attack_path[0,0,:]
        S,shield,robot_base,sword = initializeSimulation(init_pos)
        k = 0
        defence_data = np.empty((attack_path.shape[0],2,14))

        for row_no in range(1,int(np.floor(attack_path.shape[0]/3))):

            if row_no %2 == 1:
                def_target_pos = defence_path(init_pos,sword.getPosition(),shield.getPosition(),hiting_point,C)

            row = attack_path[row_no*3,0,:]
            attacker = row[:7]
            defender = def_target_pos[7:]     

            q = np.concatenate([attacker,defender]) 
            S.step(q, tau, ry.ControlMode.position)
            time.sleep(0.01)
            pos = S.get_q()
            vel = S.get_qDot()
            defence_data[k,0,:] = pos
            defence_data[k,1,:] = vel
            k += 1
            init_pos = q

            if findCollisionshield(C) == True:
                break
            if findCollision(C,"sword_1") == True:
                break

        defence_data = defence_data[:k,:,7:]
        if k > 5:  
            defence_data = interpolate_path(defence_data,len_attack)   
            total_path = np.concatenate([attack_path[:,:,:7],defence_data],axis=2)
            np.save('defence paths/'+file,total_path)    
        del S
        del C
# Out:
# -- kin_physx.cpp:addJoint:298(0) ADDING JOINT l_panda_joint7-sword_0 of type rigid with rel [0, 0, 0]
# -- kin_physx.cpp:addJoint:298(0) ADDING JOINT r_panda_joint7-shi of type rigid with rel [0, 0, 0]
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   9  A(x):    12515.8  f:    5574.21  g:          0  h:    337.994  |x-x'|:   0.789564 	stop:DeltaConverge
# ==nlp== it:   1  evals:   9  A(x):    54165.6  mu:5
# ==nlp== it:   1  evals:  14  A(x):    39292.3  f:      17116  g:          0  h:    200.315  |x-x'|:   0.345545 	stop:DeltaConverge
# ==nlp== it:   2  evals:  14  A(x):     125604  mu:25
# ==nlp== it:   2  evals:  19  A(x):    90975.6  f:    49251.9  g:          0  h:    110.353  |x-x'|:   0.318861 	stop:DeltaConverge
# ==nlp== it:   3  evals:  19  A(x):     234330  mu:125
# ==nlp== it:   3  evals:  25  A(x):     162063  f:     113854  g:          0  h:    59.1475  |x-x'|:    0.20401 	stop:DeltaConverge
# ==nlp== it:   4  evals:  25  A(x):     309678  mu:625
# ==nlp== it:   4  evals:  30  A(x):     229630  f:     181652  g:          0  h:    28.2256  |x-x'|:   0.206555 	stop:DeltaConverge
# ==nlp== it:   5  evals:  30  A(x):     387518  mu:3125
# ==nlp== it:   5  evals:  38  A(x):     333832  f:     235046  g:          0  h:    17.2923  |x-x'|:   0.198416 	stop:DeltaConverge
# ==nlp== it:   6  evals:  38  A(x):     589522  mu:10000
# ==nlp== it:   6  evals:  45  A(x):     539243  f:     302476  g:          0  h:    13.8024  |x-x'|:   0.173924 	stop:DeltaConverge
# ==nlp== it:   7  evals:  45  A(x):     790584  mu:10000
# ==nlp== it:   7  evals:  52  A(x):     781142  f:     344994  g:          0  h:    12.6273  |x-x'|:    0.13996 	stop:DeltaConverge
# ==nlp== it:   8  evals:  52  A(x):1.00428e+06  mu:10000
# ==nlp== it:   8  evals:  59  A(x):1.00144e+06  f:     371182  g:          0  h:    11.8936  |x-x'|:   0.134754 	stop:DeltaConverge
# ==nlp== it:   9  evals:  59  A(x):1.21584e+06  mu:10000
# ==nlp== it:   9  evals:  64  A(x):1.21482e+06  f:     387536  g:          0  h:    11.5649  |x-x'|:   0.108768 	stop:DeltaConverge
# ==nlp== it:  10  evals:  64  A(x):1.42602e+06  mu:10000
# ==nlp== it:  10  evals:  65  A(x):1.42567e+06  f:     394653  g:          0  h:    11.3942  |x-x'|: 0.00914517 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   5  A(x):    1709.64  f:    1641.42  g:          0  h:    46.8876  |x-x'|:   0.504223 	stop:DeltaConverge
# ==nlp== it:   1  evals:   5  A(x):    2118.92  mu:5
# ==nlp== it:   1  evals:   8  A(x):    1995.11  f:    1729.41  g:          0  h:    27.9168  |x-x'|:   0.153292 	stop:DeltaConverge
# ==nlp== it:   2  evals:   8  A(x):    3076.39  mu:25
# ==nlp== it:   2  evals:  11  A(x):    2887.08  f:     1875.2  g:          0  h:    19.6063  |x-x'|:    0.21918 	stop:DeltaConverge
# ==nlp== it:   3  evals:  11  A(x):    6949.59  mu:125
# ==nlp== it:   3  evals:  13  A(x):    6904.73  f:    1921.37  g:          0  h:    17.9546  |x-x'|:  0.0557337 	stop:DeltaConverge
# ==nlp== it:   4  evals:  13  A(x):    26942.3  mu:625
# ==nlp== it:   4  evals:  14  A(x):    26931.3  f:    1933.54  g:          0  h:    17.8037  |x-x'|: 0.00694047 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   5  A(x):    1647.48  f:    1544.06  g:          0  h:    58.0795  |x-x'|:   0.491352 	stop:DeltaConverge
# ==nlp== it:   1  evals:   5  A(x):    2268.02  mu:5
# ==nlp== it:   1  evals:   8  A(x):    2154.38  f:    1621.07  g:          0  h:    38.6846  |x-x'|:   0.132753 	stop:DeltaConverge
# ==nlp== it:   2  evals:   8  A(x):    4396.54  mu:25
# ==nlp== it:   2  evals:  12  A(x):    4236.58  f:     1749.4  g:          0  h:    30.6685  |x-x'|:   0.207352 	stop:DeltaConverge
# ==nlp== it:   3  evals:  12  A(x):    14312.8  mu:125
# ==nlp== it:   3  evals:  15  A(x):    14265.2  f:    1800.36  g:          0  h:    28.2591  |x-x'|:  0.0594942 	stop:DeltaConverge
# ==nlp== it:   4  evals:  15  A(x):    64338.5  mu:625
# ==nlp== it:   4  evals:  17  A(x):    64302.8  f:    1836.55  g:          0  h:    28.0507  |x-x'|:  0.0126825 	stop:DeltaConverge
# ==nlp== it:   5  evals:  17  A(x):     314366  mu:3125
# ==nlp== it:   5  evals:  19  A(x):     314239  f:    1956.38  g:          0  h:    27.9413  |x-x'|:  0.0145441 	stop:DeltaConverge
# ==nlp== it:   6  evals:  19  A(x):1.18874e+06  mu:10000
# ==nlp== it:   6  evals:  21  A(x):1.18856e+06  f:    2186.35  g:          0  h:      27.92  |x-x'|:  0.0122372 	stop:DeltaConverge
# ==nlp== it:   7  evals:  21  A(x):2.52065e+06  mu:10000
# ==nlp== it:   7  evals:  22  A(x): 2.5206e+06  f:    2330.79  g:          0  h:    27.9065  |x-x'|: 0.00521205 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   5  A(x):    1659.84  f:    1488.45  g:          0  h:     72.562  |x-x'|:   0.476378 	stop:DeltaConverge
# ==nlp== it:   1  evals:   5  A(x):    2688.16  mu:5
# ==nlp== it:   1  evals:   8  A(x):    2572.66  f:    1563.54  g:          0  h:    52.4321  |x-x'|:   0.115041 	stop:DeltaConverge
# ==nlp== it:   2  evals:   8  A(x):    6862.46  mu:25
# ==nlp== it:   2  evals:  12  A(x):    6712.43  f:     1687.2  g:          0  h:    44.8302  |x-x'|:   0.197577 	stop:DeltaConverge
# ==nlp== it:   3  evals:  12  A(x):    27111.5  mu:125
# ==nlp== it:   3  evals:  15  A(x):    27046.3  f:    1752.43  g:          0  h:    42.2567  |x-x'|:  0.0614819 	stop:DeltaConverge
# ==nlp== it:   4  evals:  15  A(x):     128610  mu:625
# ==nlp== it:   4  evals:  16  A(x):     128544  f:    1806.48  g:          0  h:    41.9592  |x-x'|: 0.00985026 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   5  A(x):    1790.19  f:    1516.37  g:          0  h:    88.5257  |x-x'|:   0.431048 	stop:DeltaConverge
# ==nlp== it:   1  evals:   5  A(x):    3433.12  mu:5
# ==nlp== it:   1  evals:   9  A(x):    3301.73  f:    1600.69  g:          0  h:    68.5546  |x-x'|:   0.101461 	stop:DeltaConverge
# ==nlp== it:   2  evals:   9  A(x):    10562.8  mu:25
# ==nlp== it:   2  evals:  14  A(x):      10410  f:    1734.78  g:          0  h:    61.9389  |x-x'|:   0.190671 	stop:DeltaConverge
# ==nlp== it:   3  evals:  14  A(x):    45652.1  mu:125
# ==nlp== it:   3  evals:  17  A(x):    45550.3  f:    1831.69  g:          0  h:    59.2584  |x-x'|:  0.0594723 	stop:DeltaConverge
# ==nlp== it:   4  evals:  17  A(x):     221038  mu:625
# ==nlp== it:   4  evals:  18  A(x):     220892  f:    1955.22  g:          0  h:    58.7803  |x-x'|: 0.00908653 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   5  A(x):    2090.94  f:    1683.39  g:          0  h:    106.647  |x-x'|:   0.449249 	stop:DeltaConverge
# ==nlp== it:   1  evals:   5  A(x):    4536.24  mu:5
# ==nlp== it:   1  evals:  10  A(x):    4372.39  f:     1788.2  g:          0  h:    88.9435  |x-x'|:   0.109738 	stop:DeltaConverge
# ==nlp== it:   2  evals:  10  A(x):    15421.1  mu:25
# ==nlp== it:   2  evals:  15  A(x):    15245.2  f:    1943.74  g:          0  h:    82.6639  |x-x'|:   0.169798 	stop:DeltaConverge
# ==nlp== it:   3  evals:  15  A(x):    69280.7  mu:125
# ==nlp== it:   3  evals:  19  A(x):    69084.2  f:    2129.07  g:          0  h:    78.9627  |x-x'|:   0.070606 	stop:DeltaConverge
# ==nlp== it:   4  evals:  19  A(x):     337799  mu:625
# ==nlp== it:   4  evals:  21  A(x):     337440  f:    2452.31  g:          0  h:    78.1616  |x-x'|:  0.0147915 	stop:DeltaConverge
# ==nlp== it:   5  evals:  21  A(x):1.67817e+06  mu:3125
# ==nlp== it:   5  evals:  23  A(x):1.67754e+06  f:    2927.27  g:          0  h:    77.9566  |x-x'|:   0.015829 	stop:DeltaConverge
# ==nlp== it:   6  evals:  23  A(x):6.36705e+06  mu:10000
# ==nlp== it:   6  evals:  24  A(x):6.36668e+06  f:    3205.73  g:          0  h:    77.9607  |x-x'|: 0.00899613 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   5  A(x):    2475.05  f:    1914.87  g:          0  h:    127.539  |x-x'|:   0.522525 	stop:DeltaConverge
# ==nlp== it:   1  evals:   5  A(x):    5836.14  mu:5
# ==nlp== it:   1  evals:  10  A(x):    5623.82  f:    2047.61  g:          0  h:    109.874  |x-x'|:   0.109615 	stop:DeltaConverge
# ==nlp== it:   2  evals:  10  A(x):    20916.6  mu:25
# ==nlp== it:   2  evals:  17  A(x):    20684.1  f:    2247.67  g:          0  h:    105.561  |x-x'|:   0.118934 	stop:DeltaConverge
# ==nlp== it:   3  evals:  17  A(x):    95670.4  mu:125
# ==nlp== it:   3  evals:  21  A(x):    95327.2  f:     2553.9  g:          0  h:    101.667  |x-x'|:  0.0533366 	stop:DeltaConverge
# ==nlp== it:   4  evals:  21  A(x):     467490  mu:625
# ==nlp== it:   4  evals:  23  A(x):     466705  f:    3238.79  g:          0  h:    100.361  |x-x'|:    0.02378 	stop:DeltaConverge
# ==nlp== it:   5  evals:  23  A(x): 2.3214e+06  mu:3125
# ==nlp== it:   5  evals:  26  A(x): 2.3199e+06  f:    4306.46  g:          0  h:    100.239  |x-x'|:   0.030479 	stop:DeltaConverge
# ==nlp== it:   6  evals:  26  A(x):8.80462e+06  mu:10000
# ==nlp== it:   6  evals:  28  A(x):8.80368e+06  f:    5100.99  g:          0  h:    100.401  |x-x'|:  0.0210654 	stop:DeltaConverge
# ==nlp== it:   7  evals:  28  A(x):1.86835e+07  mu:10000
# ==nlp== it:   7  evals: 112  A(x):-3.17865e+06  f:3.44053e+06  g:          0  h:    196.662  |x-x'|:    2.40809 	stop:TinyXSteps (bad:1)
# ==nlp== it:   8  evals: 112  A(x):2.91626e+07  mu:10000
# ==nlp== it:   8  evals: 143  A(x):    -195583  f:     909864  g:          0  h:    127.774  |x-x'|:    3.28496 	stop:DeltaConverge
# ==nlp== it:   9  evals: 143  A(x):1.14012e+07  mu:10000
# ==nlp== it:   9  evals: 208  A(x):6.79832e+06  f:     658784  g:          0  h:    173.034  |x-x'|:    3.70926 	stop:DeltaConverge
# ==nlp== it:  10  evals: 208  A(x):3.33563e+07  mu:10000
# ==nlp== it:  10  evals: 247  A(x):-5.70859e+06  f:1.31529e+06  g:          0  h:    120.968  |x-x'|:    2.49215 	stop:DeltaConverge
# ==nlp== it:  11  evals: 247  A(x): 8.6082e+06  mu:10000
# ==nlp== it:  11  evals: 275  A(x):3.48977e+06  f:     341715  g:          0  h:    124.704  |x-x'|:    1.86299 	stop:DeltaConverge
# ==nlp== it:  12  evals: 275  A(x):1.66426e+07  mu:10000
# ==nlp== it:  12  evals: 324  A(x):    85820.7  f:     419147  g:          0  h:    173.022  |x-x'|:    3.14197 	stop:DeltaConverge
# ==nlp== it:  13  evals: 324  A(x):2.82752e+07  mu:10000
# ==nlp== it:  13  evals: 361  A(x):-2.1973e+06  f:     289638  g:          0  h:    112.578  |x-x'|:    2.70318 	stop:DeltaConverge
# ==nlp== it:  14  evals: 361  A(x):9.97141e+06  mu:10000
# ==nlp== it:  14  evals: 380  A(x):3.86724e+06  f:     284644  g:          0  h:     116.32  |x-x'|:    1.63575 	stop:DeltaConverge
# ==nlp== it:  15  evals: 380  A(x): 1.7661e+07  mu:10000
# ==nlp== it:  15  evals: 453  A(x):   -21216.6  f:1.20932e+06  g:          0  h:    169.513  |x-x'|:    2.31386 	stop:TinyXSteps (bad:1)
# ==nlp== it:  16  evals: 453  A(x):2.63808e+07  mu:10000
# ==nlp== it:  16  evals: 495  A(x):-1.05669e+06  f:     627814  g:          0  h:    124.304  |x-x'|:    2.64396 	stop:DeltaConverge
# ==nlp== it:  17  evals: 495  A(x):1.26349e+07  mu:10000
# ==nlp== it:  17  evals: 530  A(x): 4.0025e+06  f:     430752  g:          0  h:    142.223  |x-x'|:    2.31199 	stop:DeltaConverge
# ==nlp== it:  18  evals: 530  A(x):2.01712e+07  mu:10000
# ==nlp== it:  18  evals: 603  A(x):-1.26315e+06  f:     984226  g:          0  h:    153.709  |x-x'|:    2.35469 	stop:TinyXSteps (bad:1)
# ==nlp== it:  19  evals: 603  A(x):2.05898e+07  mu:10000
# ==nlp== it:  19  evals: 639  A(x):1.12157e+06  f:1.06227e+06  g:          0  h:    137.207  |x-x'|:    2.78201 	stop:DeltaConverge
# ==nlp== it:  20  evals: 639  A(x):1.72707e+07  mu:10000
# ==nlp== it:  20  evals: 673  A(x):1.54273e+06  f:     597142  g:          0  h:    135.453  |x-x'|:    1.85675 	stop:DeltaConverge
# ==nlp== it:  21  evals: 673  A(x):1.98419e+07  mu:10000
# ==nlp== it:  21  evals: 721  A(x):      68776  f:1.13114e+06  g:          0  h:    142.567  |x-x'|:    1.87827 	stop:TinyXSteps (bad:1)
# ==nlp== it:  22  evals: 721  A(x): 1.9973e+07  mu:10000
# ==nlp== it:  22  evals: 802  A(x):     775188  f:     867119  g:          0  h:     134.56  |x-x'|:    2.03706 	stop:DeltaConverge
# ==nlp== it:  23  evals: 802  A(x):1.84763e+07  mu:10000
# ==nlp== it:  23  evals: 924  A(x):1.58554e+06  f:     588567  g:          0  h:    135.415  |x-x'|:    1.96065 	stop:TinyXSteps (bad:1)
# ==nlp== it:  24  evals: 924  A(x):1.92921e+07  mu:10000
# ==nlp== it:  24  evals:1000  A(x):     354612  f:     854706  g:          0  h:    144.546  |x-x'|:    3.31685 	stop:CritEvals (bad:2)
# ==nlp== StoppingCriterion MAX EVALS
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ==nlp== it:   0  evals:   9  A(x):    6118.45  f:    5358.56  g:          0  h:    159.626  |x-x'|:    1.37117 	stop:DeltaConverge
# ==nlp== it:   1  evals:   9  A(x):    10677.8  mu:5
# ==nlp== it:   1  evals:  12  A(x):    10535.1  f:    5450.05  g:          0  h:    141.013  |x-x'|:   0.109152 	stop:DeltaConverge
# ==nlp== it:   2  evals:  12  A(x):    32274.9  mu:25
# ==nlp== it:   2  evals:  24  A(x):    31710.3  f:    6192.96  g:          0  h:     134.48  |x-x'|:   0.494207 	stop:DeltaConverge
# ==nlp== it:   3  evals:  24  A(x):     135807  mu:125
# ==nlp== it:   3  evals:  40  A(x):     132654  f:    10622.7  g:          0  h:    124.829  |x-x'|:   0.314753 	stop:DeltaConverge
# ==nlp== it:   4  evals:  40  A(x):     633470  mu:625
# ==nlp== it:   4  evals:  64  A(x):     613687  f:    36570.9  g:          0  h:    127.056  |x-x'|:    1.12648 	stop:DeltaConverge
# ==nlp== it:   5  evals:  64  A(x):3.02915e+06  mu:3125
# ==nlp== it:   5  evals: 111  A(x):2.92395e+06  f:    83366.6  g:          0  h:    120.557  |x-x'|:     1.5254 	stop:DeltaConverge
# ==nlp== it:   6  evals: 111  A(x):1.16154e+07  mu:10000
# ==nlp== it:   6  evals: 181  A(x):7.69538e+06  f:     498430  g:          0  h:    174.469  |x-x'|:    2.14435 	stop:DeltaConverge
# ==nlp== it:   7  evals: 181  A(x):3.04002e+07  mu:10000
# ==nlp== it:   7  evals: 253  A(x):-6.50173e+06  f:     677897  g:          0  h:    147.987  |x-x'|:    2.90319 	stop:TinyXSteps (bad:1)
# ==nlp== it:   8  evals: 253  A(x):1.13261e+07  mu:10000
# ==nlp== it:   8  evals: 322  A(x):5.43053e+06  f:     829892  g:          0  h:    129.033  |x-x'|:    3.67597 	stop:DeltaConverge
# ==nlp== it:   9  evals: 322  A(x):1.93623e+07  mu:10000
# ==nlp== it:   9  evals: 561  A(x):    -435294  f:1.78664e+06  g:          0  h:    179.244  |x-x'|:     2.9015 	stop:TinyXSteps (bad:1)
# ==nlp== it:  10  evals: 561  A(x):2.59679e+07  mu:10000
# ==nlp== it:  10  evals: 764  A(x):7.19894e+06  f:2.64819e+06  g:          0  h:    152.186  |x-x'|:    2.40769 	stop:TinyXSteps (bad:2)
# ==nlp== it:  11  evals: 764  A(x):2.26706e+07  mu:10000
# ==nlp== it:  11  evals: 836  A(x):1.50161e+07  f:1.50572e+06  g:          0  h:    165.909  |x-x'|:    2.67687 	stop:TinyXSteps (bad:3)
# ==nlp== it:  12  evals: 836  A(x):3.50997e+07  mu:10000
# ==nlp== it:  12  evals: 888  A(x):1.96266e+07  f:1.51636e+06  g:          0  h:    153.863  |x-x'|:    2.13804 	stop:TinyXSteps (bad:4)
# ==nlp== it:  13  evals: 888  A(x):3.58863e+07  mu:10000
# ==nlp== it:  13  evals: 971  A(x):3.47183e+07  f: 2.1884e+06  g:          0  h:    148.449  |x-x'|:    2.04955 	stop:TinyXSteps (bad:5)
# ==nlp== it:  14  evals: 971  A(x):5.07299e+07  mu:10000
# ==nlp== it:  14  evals:1000  A(x):3.98104e+07  f:1.52889e+06  g:          0  h:    161.417  |x-x'|:    2.44029 	stop:CritEvals (bad:6)
# ==nlp== StoppingCriterion MAX EVALS
# (15, 2, 7)

# %%
import os 
import time
tau = 0.01


C = ry.Config()
C.addFile("rai-robotModels/scenarios/pandasFight.g")
q0 = C.getJointState()
C.setJointState(np.array([ 0.  , -1.  ,  0.  , -2.  ,  0.  ,  2.  ,  0.  ,  0.  ,
-1.  ,  0.  , -2.  ,  0.  ,  2.  ,  0.]))

fight_path = np.load("defence paths/path_30.npy")
init_pos = fight_path[0,0,:]
time.sleep(1)
S,shield,robot_base,sword = initializeSimulation(init_pos)
k = 0
fight_len = fight_path.shape[0]
k = 0
attack_means = []
defence_means = []
for row in fight_path:
    S.step(row[0,:], tau, ry.ControlMode.position)
    vel = S.get_qDot()
    attack_means.append(np.mean(np.abs(vel[:7])))
    defence_means.append(np.mean(np.abs(vel[7:])))
    C.view()
    time.sleep(0.02)
    k+=1
print(f"attack mean: {np.mean(attack_means)}")
print(f"defence mean: {np.mean(defence_means)}")
del S
del C
# Out:
# -- kin_physx.cpp:addJoint:298(0) ADDING JOINT l_panda_joint7-sword_0 of type rigid with rel [0, 0, 0]
# -- kin_physx.cpp:addJoint:298(0) ADDING JOINT r_panda_joint7-shi of type rigid with rel [0, 0, 0]
# attack mean: 0.45396211167370476
# defence mean: 0.6738642526552239
